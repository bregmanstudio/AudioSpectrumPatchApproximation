# %% [markdown]
# <h1>Audio Spectrum Patch Approximation via Over-complete Dictionaries</h1>
# <h3>Michael A. Casey, 2014-2015 Bregman Media Labs, Dartmouth College</h3>

# %% [markdown]
# ### Constant-Q Time-Frequency Analysis

# %% [markdown]
# Analyze 10s of a natural scene (field recording) using a log frequency scale (constant-Q transform)
# and plot the resulting time series and its time-averaged constant-Q spectrum.

# %%
from pylab import *
rcParams['figure.figsize'] = (12.0, 8.0)

# %%
from bregman.suite import *
F = LogFrequencySpectrum('chernobyl.wav',nhop=1024, nfft=8192, wfft=4096, npo=24) # constant-Q transform
subplot(211)
F.feature_plot(normalize=True, nofig=True, cmap=cm.hot) # plot the transform
title('Constant-Q Spectrum (Linear Amplitude)', fontsize=14)
subplot(212)
plot(F.X.sum(1)) # and the time-averaged constant-Q spectrum
title('Mean Constant-Q Spectrum: Log Amplitude ', fontsize=14)
xticks(arange(0,100,8), F._logfrqs[0:-1:8].round())
xlabel('Frequency (Hz)')
ylabel('Log Amplitude')
grid();axis('tight');ax=colorbar();ax.ax.set_visible(False)

# %% [markdown]
# ### Inverting the analysis back to audio

# %% [markdown]
# Invert the constant-Q transform to an audio signal, using inverse constant-Q transform and inverse short-time Fourier transform.

# %%
xh = F.inverse()
play(balance_signal(xh)) # Check the resynthesis without sparse coding
# Out:
# Period size is 64 , Buffer size is 22050

# %% [markdown]
# ### Method 1. Sparse approximation dictionary learning, using mini bach gradient learning

# %% [markdown]
# Learn sparse codes from data using dictionary learnng on 16x16 patches of the constant-Q transform.

# %%
import AudioSpectrumPatchApproximation as A # M. Casey's multi-scale 2D spectrogram patch sprase approximation library
reload(A) # for debugging
# Out:
# <module 'AudioSpectrumPatchApproximation' from 'AudioSpectrumPatchApproximation.pyc'>

# %%
s1 = A.SparseApproxSpectrum(n_components=9, patch_size=(11,11)) # learn 9 components of 16x16 patches
s1.extract_codes(F.X) # Learn a dictionary of patches for spectrogram
s1.plot_codes(cbar=1, cmap=cm.hot) # show the learned codes
# Out:
# (35700, 121)
# Dictionary learning from data...

# %%
pargs = {'normalize':True, 'dbscale':True, 'cmap':cm.hot, 'vmax':0, 'vmin':-45} # plot arguments
s1.reconstruct_individual_spectra(plotting=1, **pargs)
figure()
subplot(211); feature_plot(F.X, nofig=True, **pargs)
subplot(212); feature_plot(s1.X_hat, nofig=True, **pargs)

# %%
X_hat = s1.X_hat_l[6] # <- change the patch to reconstruct here
x_hat = F.inverse(X_hat) # , Phi_hat=(rand(*F.STFT.shape)*2-1)*pi) 
play(balance_signal(x_hat))
feature_plot(X_hat, **pargs)
# Out:
# Period size is 64 , Buffer size is 22050

# %% [markdown]
# <h2>Method 2: Decomposition with a "Gabor field" dictionary</h2>

# %%
F = LogFrequencySpectrum('chernobyl.wav',nhop=1024, nfft=8192, wfft=4096, npo=24) # constant-Q transform
s2 = A.SparseApproxSpectrum(n_components=16, patch_size=(11,11))
s2.make_gabor_field(F.X) # Generate a dictionary of Gabor patches for spectrogram
s2.plot_codes(cbar=1,cmap=cm.hot) # show the learned codes
# Out:
# (35700, 121)

# %% [markdown]
# Reconstruct the constant-Q spectrogram using each learned patch basis. Do this for each patch separately.

# %%
pargs = {'normalize':True, 'dbscale':True, 'cmap':cm.hot, 'vmax':0, 'vmin':-45} # plot arguments
s2.reconstruct_individual_spectra(plotting=1, **pargs)
figure()
subplot(211); feature_plot(F.X, nofig=True, **pargs)
subplot(212); feature_plot(s2.X_hat, nofig=True, **pargs)

# %%
X_hat = s2.X_hat_l[6] # <- change the patch to reconstruct here
x_hat = F.inverse(X_hat) #, Phi_hat=(rand(*F.STFT.shape)*2-1)*pi) 
play(balance_signal(x_hat))
feature_plot(X_hat, **pargs)
# Out:
# Period size is 64 , Buffer size is 22050
